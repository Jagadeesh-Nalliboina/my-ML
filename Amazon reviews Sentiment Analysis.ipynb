# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data
comments_df = pd.read_csv('product_dataset.csv')
comments_df
# Out:
#       rating_by_user       date              type  \
# 0                  5  31-Jul-18  Charcoal Fabric
# 1                  5  31-Jul-18  Charcoal Fabric
# 2                  4  31-Jul-18    Walnut Finish
# 3                  5  31-Jul-18  Charcoal Fabric
# 4                  5  31-Jul-18  Charcoal Fabric
# ...              ...        ...               ...
# 3145               5  30-Jul-18        Black  Dot
# 3146               5  30-Jul-18        Black  Dot
# 3147               5  30-Jul-18        Black  Dot
# 3148               5  30-Jul-18        White  Dot
# 3149               4  29-Jul-18        Black  Dot
#
#                                            user_reviews  user_feedback
# 0                                         Love my Echo!              1
# 1                                             Loved it!              1
# 2     Sometimes while playing a game, you can answer...              1
# 3     I have had a lot of fun with this thing. My 4 ...              1
# ...

# %%
# View the DataFrame Information
comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rating_by_user  3150 non-null   int64
#  1   date            3150 non-null   object
#  2   type            3150 non-null   object
#  3   user_reviews    3150 non-null   object
#  4   user_feedback   3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %%
# View DataFrame Statistical Summary
comments_df.describe()
# Out:
#        rating_by_user  user_feedback
# count     3150.000000    3150.000000
# mean         4.463175       0.918413
# std          1.068506       0.273778
# min          1.000000       0.000000
# 25%          4.000000       1.000000
# 50%          5.000000       1.000000
# 75%          5.000000       1.000000
# max          5.000000       1.000000

# %%
# Plot the count plot for the ratings
import seaborn as sns
sns.countplot(y = comments_df['rating_by_user'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='rating_by_user'>

# %%
# Let's get the length of the verified_reviews column
comments_df['review_length'] = comments_df['user_reviews'].apply(len)

# %%
comments_df
# Out:
#       rating_by_user       date              type  \
# 0                  5  31-Jul-18  Charcoal Fabric
# 1                  5  31-Jul-18  Charcoal Fabric
# 2                  4  31-Jul-18    Walnut Finish
# 3                  5  31-Jul-18  Charcoal Fabric
# 4                  5  31-Jul-18  Charcoal Fabric
# ...              ...        ...               ...
# 3145               5  30-Jul-18        Black  Dot
# 3146               5  30-Jul-18        Black  Dot
# 3147               5  30-Jul-18        Black  Dot
# 3148               5  30-Jul-18        White  Dot
# 3149               4  29-Jul-18        Black  Dot
#
#                                            user_reviews  user_feedback  \
# 0                                         Love my Echo!              1
# 1                                             Loved it!              1
# 2     Sometimes while playing a game, you can answer...              1
# 3     I have had a lot of fun with this thing. My 4 ...              1
# ...

# %%
# Plot the histogram for the length
plt.hist(comments_df['review_length'],bins=20)
# Out:
# (array([2.245e+03, 5.370e+02, 1.880e+02, 7.800e+01, 5.100e+01, 2.100e+01,
#         1.500e+01, 3.000e+00, 1.000e+00, 5.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([1.0000e+00, 1.4350e+02, 2.8600e+02, 4.2850e+02, 5.7100e+02,
#         7.1350e+02, 8.5600e+02, 9.9850e+02, 1.1410e+03, 1.2835e+03,
#         1.4260e+03, 1.5685e+03, 1.7110e+03, 1.8535e+03, 1.9960e+03,
#         2.1385e+03, 2.2810e+03, 2.4235e+03, 2.5660e+03, 2.7085e+03,
#         2.8510e+03]),
#  <BarContainer object of 20 artists>)

# %%
# Apply the describe method to get statistical summary
comments_df.describe()
# Out:
#        rating_by_user  user_feedback  review_length
# count     3150.000000    3150.000000    3150.000000
# mean         4.463175       0.918413     132.049524
# std          1.068506       0.273778     182.099952
# min          1.000000       0.000000       1.000000
# 25%          4.000000       1.000000      30.000000
# 50%          5.000000       1.000000      74.000000
# 75%          5.000000       1.000000     165.000000
# max          5.000000       1.000000    2851.000000

# %%
# Plot the countplot for feedback
sns.countplot(x = comments_df['user_feedback'])
# Out:
# <AxesSubplot:xlabel='user_feedback', ylabel='count'>

# %%
# Obtain only the positive reviews
positive_reviews = comments_df[comments_df['user_feedback'] == 1]
positive_reviews
# Out:
#       rating_by_user       date              type  \
# 0                  5  31-Jul-18  Charcoal Fabric
# 1                  5  31-Jul-18  Charcoal Fabric
# 2                  4  31-Jul-18    Walnut Finish
# 3                  5  31-Jul-18  Charcoal Fabric
# 4                  5  31-Jul-18  Charcoal Fabric
# ...              ...        ...               ...
# 3145               5  30-Jul-18        Black  Dot
# 3146               5  30-Jul-18        Black  Dot
# 3147               5  30-Jul-18        Black  Dot
# 3148               5  30-Jul-18        White  Dot
# 3149               4  29-Jul-18        Black  Dot
#
#                                            user_reviews  user_feedback  \
# 0                                         Love my Echo!              1
# 1                                             Loved it!              1
# 2     Sometimes while playing a game, you can answer...              1
# 3     I have had a lot of fun with this thing. My 4 ...              1
# ...

# %%
# Obtain the negative reviews only
negative_reviews = comments_df[comments_df['user_feedback'] == 0]
negative_reviews
# Out:
#       rating_by_user       date                  type  \
# 46                 2  30-Jul-18      Charcoal Fabric
# 111                2  30-Jul-18      Charcoal Fabric
# 141                1  30-Jul-18      Charcoal Fabric
# 162                1  30-Jul-18     Sandstone Fabric
# 176                2  30-Jul-18  Heather Gray Fabric
# ...              ...        ...                   ...
# 3047               1  30-Jul-18            Black  Dot
# 3048               1  30-Jul-18            White  Dot
# 3067               2  30-Jul-18            Black  Dot
# 3091               1  30-Jul-18            Black  Dot
# 3096               1  30-Jul-18            White  Dot
#
#                                            user_reviews  user_feedback  \
# 46    It's like Siri, in fact, Siri answers more acc...              0
# 111   Sound is terrible if u want good music too get...              0
# 141                                  Not much features.              0
# ...

# %%
# Convert to list format
sentences = positive_reviews['user_reviews'].tolist()
len(sentences)
# Out:
# 2893

# %%
# Join all reviews into one large string
sentences_as_one_string =" ".join(sentences)

# %%
sentences_as_one_string
# Out:
# 'Love my Echo! Loved it! Sometimes while playing a game, you can answer a question correctly but Alexa says you got it wrong and answers the same as you.  I like being able to turn lights on and off while away from home. I have had a lot of fun with this thing. My 4 yr old learns about dinosaurs, i control the lights and play games like categories. Has nice sound when playing music as well. Music I received the echo as a gift. I needed another Bluetooth or something to play music easily accessible, and found this smart speaker. Can’t wait to see what else it can do. Without having a cellphone, I cannot use many of her features. I have an iPad but do not see that of any use.  It IS a great alarm.  If u r almost deaf, you can hear her alarm in the bedroom from out in the living room, so that is reason enough to keep her.It is fun to ask random questions to hear her response.  She does not seem to be very smartbon politics yet. I think this is the 5th one I\'ve purchased. I\'m working o
# ...

# %%
pip install wordcloud
# Out:
# ...
#      ------------------------------------ 153.1/153.1 kB 380.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

plt.figure(figsize=(20,20))
plt.imshow(WordCloud().generate(sentences_as_one_string))

# %%
sentences = negative_reviews['user_reviews'].tolist()
len(sentences)
sentences_as_one_string =" ".join(sentences)
plt.figure(figsize = (20,20))
plt.imshow(WordCloud().generate(sentences_as_one_string))

# %%
import nltk # Natural Language tool kit 
nltk.download('stopwords')

# You have to download stopwords Package to execute this command
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moduk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
# ...

# %%
import string
def comment_processing(message):
    char_list=[]
    for ele in message:
        if ele not in string.punctuation:
            char_list.append(ele)
    char_join = ''.join(char_list)
    char_clean = []
    for item in char_join.split():
        if item.lower() not in stopwords.words('english'):
            char_clean.append(item)
    return char_clean

# %%
# Let's test the newly added function
comments_df_clean = comments_df['user_reviews'].apply(comment_processing)

# %%
# show the original review
print(comments_df['user_reviews'][10])
# Out:
# I sent it to my 85 year old Dad, and he talks to it constantly.

# %%
# show the cleaned up version
print(comments_df_clean[5])
# Out:
# ['received', 'echo', 'gift', 'needed', 'another', 'Bluetooth', 'something', 'play', 'music', 'easily', 'accessible', 'found', 'smart', 'speaker', 'Can’t', 'wait', 'see', 'else']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = message_cleaning)
reviews_countvectorizer = vectorizer.fit_transform(comments_df['user_reviews'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\4163572212.py in <module>
#       1 from sklearn.feature_extraction.text import CountVectorizer
# ----> 2 vectorizer = CountVectorizer(analyzer = message_cleaning)
#       3 reviews_countvectorizer = vectorizer.fit_transform(comments_df['user_reviews'])
#
# NameError: name 'message_cleaning' is not defined

# %%
X = pd.DataFrame(reviews_countvectorizer.toarray())
y = comments_df['user_feedback']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\184987402.py in <module>
# ----> 1 X = pd.DataFrame(reviews_countvectorizer.toarray())
#       2 y = comments_df['user_feedback']
#
# NameError: name 'reviews_countvectorizer' is not defined

# %%
#Splitting training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\541909024.py in <module>
#       1 #Splitting training and testing data
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)
#
# NameError: name 'X' is not defined

# %%
#Applying Naive Bayes algorithm
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix
NB_classifier = MultinomialNB()
NB_classifier.fit(X_train, y_train)
# Predicting the Test set results
y_predict_test = NB_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot=True)
print(classification_report(y_test, y_predict_test))

# %%
#Applying LogisticRegression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Predicting the Test set results
y_pred = model.predict(X_test)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot = True)
print(classification_report(y_test, y_pred))

# %%
#Applying GradientBoostClassifer
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train)
# Predicting the Test set results
y_pred = model.predict(X_test)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot = True)
print(classification_report(y_test, y_pred))
